# %% [markdown]
# <a href="https://colab.research.google.com/github/VALERIAMARTINEZ128/PROFE-ejemplo-valeria-1341/blob/main/profe_clase_automovil_valeria_1341_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####valeria yaretzi 1341 fecha 29/abril/2026
# #### clase automovil  con 3 atributos funciones leerdatos() , mostrardatos()
# #### que sea interactivo --> los input
# ### crear 3 objetos carro1,carro2,carro3
# ### no usar while true if,

# %% [markdown]
# ![texto vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/PROFE-ejemplo-valeria-1341/refs/heads/main/infoclaseauto.png)

# %%
# clase automovil , atributos ,marca, placa , precio
# funciones leerdatos(), mostrardatos(),
# crear 3 objetos carro1,carro2,carro3
class automovil:
    def __init__(self,marca,placa,precio):
        self.marca = marca
        self.placa = placa
        self.precio = precio
    def leerdatos(self):
        self.marca = input("ingrese la marca: ")
        self.placa = input("ingrese la placa: ")
        self.precio = input("ingrese el precio: ")
        return self.marca,self.placa,self.precio

    def mostrardatos(self):
        print("marca: ",self.marca)
        print("placa: ",self.placa)
        print("precio: ",self.precio)
        return self.marca,self.placa,self.precio
# fin de la clase automovil
# creando los objetos carro1,carro2,carro3
carro1 = automovil("", "", "")
print("carro numero 1 ")
carro1.leerdatos()
carro1.mostrardatos()
print("*-*-*-* ")
carro2 = automovil("", "", "")
print("carro numero 2 ")
carro2.leerdatos()
carro2.mostrardatos()
print("*-*-")
carro3 = automovil("", "", "")
print("carro numero 3 ")
carro3.leerdatos()
carro3.mostrardatos()
print("sofware realizado por valeria yaretzi lopez martinez NL = 32 ")
# Out:
# carro numero 1
# ingrese la marca: toyota
# ingrese la placa: 2354
# ingrese el precio: 50,000
# marca:  toyota
# placa:  2354
# precio:  50,000
# *-*-*-*
# carro numero 2
# ingrese la marca: ram
# ingrese la placa: 25769
# ingrese el precio: 90,000
# marca:  ram
# placa:  25769
# precio:  90,000
# *-*-
# carro numero 3
# ingrese la marca: ford
# ingrese la placa: 87589
# ingrese el precio: 80,000
# marca:  ford
# placa:  87589
# precio:  80,000
# sofware realizado por valeria yaretzi lopez martinez NL = 32

# %% [markdown]
# ![texto vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/PROFE-ejemplo-valeria-1341/refs/heads/main/mi%C3%A9%2C%207_48.png)
